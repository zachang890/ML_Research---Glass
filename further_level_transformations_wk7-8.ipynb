# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

transformed_data = pd.read_csv("./transformed_samples_by_features.csv").drop(columns=["Unnamed: 0"])
transformed_data.head()
# Out:
#    AtomicNumber  AtomicPeriod  AtomicGroup  AtomicWeight  EmpiricalRadius  \
# 0      0.227956  4.080268e-01     0.598951      0.178778         0.472892
# 1      0.201553  4.042553e-01     0.320124      0.160136         0.689074
# 2      0.033039  4.440892e-16     0.680963      0.024975         0.096190
# 3      0.175965  2.833333e-01     0.645585      0.136069         0.333519
# 4      0.220507  3.913043e-01     0.598951      0.172803         0.459683
#
#    CalculaterRadius  MolarVolume  Electronegativity  AbsoluteMeltingPoint  \
# 0          0.443186     0.331975           0.495368              0.489134
# 1          0.664527     0.443094           0.258694              0.477728
# 2          0.141274     0.041467           0.599047              0.939462
# 3          0.346586     0.226674           0.546330              0.507368
# 4          0.424822     0.323690           0.502600              0.485322
#
#    Oxidation_States  ...  AtomicGroup Inversed Log  AtomicWeight Inversed Log  \
# 0          0.507246  ...                  2.051597                  -1.385785
# 1          0.248227  ...                 -7.191740                  -1.202313
# 2          0.369248  ...                  1.624027                  -0.371762
# 3          0.544444  ...                  1.778088                  -1.005437
# 4          0.507246  ...                  2.051597                  -1.323444
#
#    EmpiricalRadius Inversed Log  CalculaterRadius Inversed Log  \
# 0                      3.982295                       5.369554
# 1                      1.593388                       1.691131
# 2                     -0.745476                      -1.044877
# 3                    -10.198434                     -16.771737
# 4                      4.488714                       6.948542
#
#    MolarVolume Inversed Log  Electronegativity Inversed Log  \
# 0                 -9.737471                        3.360833
# 1                  5.375574                       -2.840023
# 2                 -0.458114                        2.050923
# 3                 -2.065088                        2.528652
# 4                 -7.814407                        3.204726
#
#    AbsoluteMeltingPoint Inversed Log  Oxidation_States Inversed Log  \
# 0                           3.510232                       3.112922
# 1                           3.827216                      -2.541866
# 2                           1.066607                     269.300549
# 3                           3.110607                       2.550951
# 4                           3.609356                       3.112922
#
#    Bond dissociation energy Inversed Log  Assumed CN Inversed Log
# 0                               2.690762                32.540299
# 1                               3.473337                 2.089465
# 2                               1.050605                -0.763998
# 3                               1.997142                -2.045890
# 4                               2.795798               202.922160
#
# [5 rows x 132 columns]

# %%
level2_transform = pd.DataFrame()
column_names = transformed_data.columns

for column_index in range(len(transformed_data.columns) - 1):
    for second_column_index in range(column_index, len(transformed_data.columns)):
        level2_transform[column_names[column_index] + " Times " + column_names[second_column_index]] = transformed_data[column_names[column_index]] * transformed_data[column_names[second_column_index]]

# %%
#Algorithm behind cleaning duplicates
to_remove = []
level2_column_names = level2_transform.columns
for nontransform_column_index in range(len(transformed_data.columns)):
    for secondtransform_index in range(len(level2_transform.columns)):
        true_false = np.where(level2_transform[level2_column_names[secondtransform_index]] == transformed_data[column_names[nontransform_column_index]], True, False)
        if true_false[0] == True:
            to_remove.append(level2_column_names[secondtransform_index])

to_remove
# Out:
# ['AtomicPeriod Square Root Times AtomicPeriod Square Root',
#  'AtomicWeight Square Root Times AtomicWeight Square Root',
#  'CalculaterRadius Square Root Times CalculaterRadius Square Root',
#  'AbsoluteMeltingPoint Square Root Times AbsoluteMeltingPoint Square Root',
#  'AtomicPeriod Times AtomicPeriod',
#  'AtomicWeight Times AtomicWeight',
#  'EmpiricalRadius Times EmpiricalRadius',
#  'CalculaterRadius Times CalculaterRadius',
#  'Oxidation_States Times Oxidation_States',
#  'Bond dissociation energy Times Bond dissociation energy',
#  'Assumed CN Times Assumed CN',
#  'AtomicNumber Times AtomicNumber Square',
#  'EmpiricalRadius Times EmpiricalRadius Square',
#  'AbsoluteMeltingPoint Times AbsoluteMeltingPoint Square',
#  'Oxidation_States Times Oxidation_States Square',
#  'Bond dissociation energy Times Bond dissociation energy Square']

# %%
#Example of how np.where works
trial_df = pd.DataFrame()
trial_df["AtomicNumber Times AtomicNumber"] = level2_transform["AtomicNumber Times AtomicNumber"]
trial_df["AtomicNumber Squared"] = transformed_data["AtomicNumber"] ** 2

trial_df.at[0, "AtomicNumber Times AtomicNumber"] = 1000
true_false = np.where(trial_df["AtomicNumber Times AtomicNumber"] == trial_df["AtomicNumber Squared"], True, False)
true_false
# Out:
# array([False,  True,  True, ...,  True,  True,  True])

# %%
level2_transform
# Out:
#       AtomicNumber Times AtomicNumber  AtomicNumber Times AtomicPeriod  \
# 0                            0.051964                     9.301204e-02
# 1                            0.040624                     8.147884e-02
# 2                            0.001092                     1.467224e-17
# 3                            0.030964                     4.985667e-02
# 4                            0.048623                     8.628541e-02
# ...                               ...                              ...
# 1598                         0.062891                     1.020445e-01
# 1599                         0.048623                     9.829751e-02
# 1600                         0.048623                     9.845080e-02
# 1601                         0.006909                     1.268478e-02
# 1602                         0.003900                     4.700788e-03
#
#       AtomicNumber Times AtomicGroup  AtomicNumber Times AtomicWeight  \
# 0                           0.136534                         0.040753
# 1                           0.064522                         0.032276
# 2                           0.022498                         0.000825
# 3                           0.113600                         0.023943
# 4                           0.132073                         0.038104
# ...                              ...                              ...
# 1598                        0.179480                         0.050040
# 1599                        0.069429                         0.038689
# 1600                        0.070402                         0.038733
# 1601                        0.034677                         0.005563
# 1602                        0.038742                         0.003075
#
#       AtomicNumber Times EmpiricalRadius  AtomicNumber Times CalculaterRadius  \
# 0                               0.107798                             0.101027
# 1                               0.138885                             0.133937
# 2                               0.003178                             0.004668
# 3                               0.058688                             0.060987
# 4                               0.101363                             0.093676
# ...                                  ...                                  ...
# 1598                            0.074452                             0.067978
# 1599                            0.161495                             0.153512
# 1600                            0.161658                             0.153078
# 1601                            0.035070                             0.036165
# 1602                            0.012996                             0.014335
#
#       AtomicNumber Times MolarVolume  AtomicNumber Times Electronegativity  \
# 0                           0.075676                              0.112922
# 1                           0.089307                              0.052141
# 2                           0.001370                              0.019792
# 3                           0.039887                              0.096135
# 4                           0.071376                              0.110827
# ...                              ...                                   ...
# 1598                        0.086049                              0.183042
# 1599                        0.102786                              0.052347
# 1600                        0.101949                              0.051731
# 1601                        0.020485                              0.030045
# 1602                        0.007591                              0.033827
#
#       AtomicNumber Times AbsoluteMeltingPoint  \
# 0                                    0.111501
# 1                                    0.096288
# 2                                    0.031039
# 3                                    0.089279
# 4                                    0.107017
# ...                                       ...
# 1598                                 0.047624
# 1599                                 0.091220
# 1600                                 0.090009
# 1601                                 0.067160
# 1602                                 0.056538
#
#       AtomicNumber Times Oxidation_States  ...  \
# 0                                0.115630  ...
# 1                                0.050031  ...
# 2                                0.012200  ...
# 3                                0.095803  ...
# 4                                0.111851  ...
# ...                                   ...  ...
# 1598                             0.188488  ...
# 1599                             0.055795  ...
# 1600                             0.055080  ...
# 1601                             0.015112  ...
# 1602                             0.020370  ...
#
#       Electronegativity Inversed Log Times Assumed CN Inversed Log  \
# 0                                            109.362507
# 1                                             -5.934128
# 2                                             -1.566901
# 3                                             -5.173343
# 4                                            650.309939
# ...                                                 ...
# 1598                                          -2.904472
# 1599                                          -4.374985
# 1600                                          -4.281010
# 1601                                        -615.899605
# 1602                                          -4.842369
#
#       AbsoluteMeltingPoint Inversed Log Times AbsoluteMeltingPoint Inversed Log  \
# 0                                             12.321728
# 1                                             14.647580
# 2                                              1.137651
# 3                                              9.675873
# 4                                             13.027450
# ...                                                 ...
# 1598                                           2.287109
# 1599                                          72.622906
# 1600                                          92.495077
# 1601                                           1.615463
# 1602                                           1.233202
#
#       AbsoluteMeltingPoint Inversed Log Times Oxidation_States Inversed Log  \
# 0                                             10.927079
# 1                                             -9.728271
# 2                                            287.237894
# 3                                              7.935006
# 4                                             11.235644
# ...                                                 ...
# 1598                                          -2.116743
# 1599                                         -22.770870
# 1600                                         -24.841664
# 1601                                          -1.803297
# 1602                                          -9.227048
#
#       AbsoluteMeltingPoint Inversed Log Times Bond dissociation energy Inversed Log  \
# 0                                              9.445198
# 1                                             13.293210
# 2                                              1.120583
# 3                                              6.212323
# 4                                             10.091031
# ...                                                 ...
# 1598                                           2.430025
# 1599                                          59.548011
# 1600                                          79.965622
# 1601                                           1.686922
# 1602                                           1.253433
#
#       AbsoluteMeltingPoint Inversed Log Times Assumed CN Inversed Log  \
# 0                                            114.223996
# 1                                              7.996832
# 2                                             -0.814886
# 3                                             -6.363958
# 4                                            732.418302
# ...                                                 ...
# 1598                                           3.009447
# 1599                                          16.331512
# 1600                                          18.522576
# 1601                                          13.787341
# 1602                                          -2.080185
#
#       Oxidation_States Inversed Log Times Oxidation_States Inversed Log  \
# 0                                              9.690285
# 1                                              6.461085
# 2                                          72522.785425
# 3                                              6.507352
# 4                                              9.690285
# ...                                                 ...
# 1598                                           1.959067
# 1599                                           7.139793
# 1600                                           6.671796
# 1601                                           2.012971
# 1602                                          69.038507
#
#       Oxidation_States Inversed Log Times Bond dissociation energy Inversed Log  \
# 0                                              8.376133
# 1                                             -8.828759
# 2                                            282.928479
# 3                                              5.094611
# 4                                              8.703103
# ...                                                 ...
# 1598                                          -2.249014
# 1599                                         -18.671244
# 1600                                         -21.476593
# 1601                                          -1.883065
# 1602                                          -9.378423
#
#       Oxidation_States Inversed Log Times Assumed CN Inversed Log  \
# 0                                            101.295422
# 1                                             -5.311141
# 2                                           -205.745143
# 3                                             -5.218965
# 4                                            631.680914
# ...                                                 ...
# 1598                                          -2.785275
# 1599                                          -5.120736
# 1600                                          -4.974661
# 1601                                         -15.390428
# 1602                                          15.564338
#
#       Bond dissociation energy Inversed Log Times Bond dissociation energy Inversed Log  \
# 0                                              7.240200
# 1                                             12.064071
# 2                                              1.103771
# 3                                              3.988576
# 4                                              7.816488
# ...                                                 ...
# 1598                                           2.581873
# 1599                                          48.827096
# 1600                                          69.133417
# 1601                                           1.761542
# 1602                                           1.273996
#
#       Bond dissociation energy Inversed Log Times Assumed CN Inversed Log
# 0                                             87.558198
# 1                                              7.257416
# 2                                             -0.802660
# 3                                             -4.085932
# 4                                            567.329436
# ...                                                 ...
# 1598                                           3.197502
# 1599                                          13.391216
# 1600                                          16.013493
# 1601                                          14.397215
# 1602                                          -2.114312
#
# [1603 rows x 8777 columns]

# %%
a = level2_transform #a is here to save the original transform just in case
level2_transform = level2_transform.drop(columns=to_remove)

# for remove in to_remove:
#     print(remove)
#     level2_transform = level2_transform.drop(columns=[remove], axis = 1)
# print(len(level2_transform.columns))
# Out:
# 8761
# Index(['AtomicNumber Times AtomicNumber', 'AtomicNumber Times AtomicPeriod',
#        'AtomicNumber Times AtomicGroup', 'AtomicNumber Times AtomicWeight',
#        'AtomicNumber Times EmpiricalRadius',
#        'AtomicNumber Times CalculaterRadius', 'AtomicNumber Times MolarVolume',
#        'AtomicNumber Times Electronegativity',
#        'AtomicNumber Times AbsoluteMeltingPoint',
#        'AtomicNumber Times Oxidation_States',
#        ...
#        'Electronegativity Inversed Log Times Assumed CN Inversed Log',
#        'AbsoluteMeltingPoint Inversed Log Times AbsoluteMeltingPoint Inversed Log',
#        'AbsoluteMeltingPoint Inversed Log Times Oxidation_States Inversed Log',
#        'AbsoluteMeltingPoint Inversed Log Times Bond dissociation energy Inversed Log',
#        'AbsoluteMeltingPoint Inversed Log Times Assumed CN Inversed Log',
#        'Oxidation_States Inversed Log Times Oxidation_States Inversed Log',
#        'Oxidation_States Inversed Log Times Bond dissociation energy Inversed Log',
#        'Oxidation_States Inversed Log Times Assumed CN Inversed Log',
#        'Bond dissociation energy Inversed Log Times Bond dissociation energy Inversed Log',
#        'Bond dissociation energy Inversed Log Times Assumed CN Inversed Log'],
#       dtype='object', length=8761)
# 0       0.051964
# 1       0.040624
# 2       0.001092
# 3       0.030964
# 4       0.048623
#           ...
# 1598    0.062891
# 1599    0.048623
# 1600    0.048623
# 1601    0.006909
# 1602    0.003900
# Name: AtomicNumber Times AtomicNumber, Length: 1603, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-9a68ba2007e2> in <module>
#       4 print(level2_transform["AtomicNumber Times AtomicNumber"])# to_remove[0]])
#       5 a = level2_transform
# ----> 6 level2_transform = level2_transform.drop(columns=to_remove)
#       7
#       8 # for remove in to_remove:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['AtomicPeriod Square Root Times AtomicPeriod Square Root'\n 'AtomicWeight Square Root Times AtomicWeight Square Root'\n 'CalculaterRadius Square Root Times CalculaterRadius Square Root'\n 'AbsoluteMeltingPoint Square Root Times AbsoluteMeltingPoint Square Root'\n 'AtomicPeriod Times AtomicPeriod' 'AtomicWeight Times AtomicWeight'\n 'EmpiricalRadius Times EmpiricalRadius'\n 'CalculaterRadius Times CalculaterRadius'\n 'Oxidation_States Times Oxidation_States'\n 'Bond dissociation energy Times Bond dissociation energy'\n 'Assumed CN Times Assumed CN' 'AtomicNumber Times AtomicNumber Square'\n 'EmpiricalRadius Times EmpiricalRadius Square'\n 'AbsoluteMeltingPoint Times AbsoluteMeltingPoint Square'\n 'Oxidation_States Times Oxidation_States Square'\n 'Bond dissociation energy Times Bond dissociation energy Square'] not found in axis"

# %%
level2_transform #now convert to csv and use wk5-6 to retrain
level2_transform.to_csv(r"./second_level_transformations.csv")
